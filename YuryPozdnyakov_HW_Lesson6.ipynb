# %% [markdown]
# ### Курс «Теория вероятностей и математическая статистика»
# ### Практическое задание к уроку 6
# ## Тема «Взаимосвязь величин. Параметрические и непараметрические показатели корреляции. Корреляционный анализ»

# %% [markdown]
# __Задача 1__
#
# Даны значения величины заработной платы заемщиков банка (`salary`) и значения их поведенческого кредитного скоринга (`scoring`):
# ```
# salary = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110]
# scoring = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832]
# ```
# 1. Найдите ковариацию этих двух величин: сначала без использования специальных функций, а затем с помощью функции `numpy.cov`. Полученные значения должны быть равны.
# 2. Найдите коэффициент корреляции Пирсона: с помощью ковариации и средних квадратических отклонений двух признаков, а затем с помощью специальных функций из библиотек `numpy` и `pandas`.

# %%
import numpy as np
import pandas as pd
from scipy import stats

salary = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
scoring = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

salary_mean = salary.mean()
scoring_mean = scoring.mean()

# Ковариация двух величин по формуле:
cov = ((salary - salary_mean) * (scoring - scoring_mean)).sum() / (salary.shape[0] - 1)
cov
# Out:
# 10175.37777777778

# %%
# Ковариация двух величин с помощью функции numpy.cov:
np.cov(salary, scoring)
# Out:
# array([[ 3882.93333333, 10175.37777778],
#        [10175.37777778, 33854.32222222]])

# %%
# Коэффициент корреляции Пирсона с помощью ковариации и 
# средних квадратических отклонений двух признаков
corr = cov / (salary.std(ddof = 1) * scoring.std(ddof = 1))
corr
# Out:
# 0.8874900920739164

# %%
# Коэффициент корреляции Пирсона с помощью numpy
np.corrcoef(salary, scoring)[0][1]
# Out:
# 0.8874900920739159

# %%
corr_df = pd.DataFrame([salary,scoring],index=['salary','scoring'])

# Коэффициент корреляции Пирсона с помощью pandas
corr_df.transpose().corr().loc['salary','scoring']
# Out:
# 0.8874900920739168

# %% [markdown]
# __Задача 2__
#
# Измерены значения IQ выборки студентов, обучающихся в местных технических вузах:
# ```
# 131, 125, 115, 122, 131, 115, 107, 99, 125, 111
# ```
# Известно, что в генеральной совокупности IQ распределен нормально. Найдите доверительный интервал для математического ожидания с надежностью 0.95.

# %%
iq = np.array([131, 125, 115, 122, 131, 115, 107, 99, 125, 111])
p = 0.95
alpha = 1 - p
n = iq.shape[0]
mean = iq.mean()
std = iq.std(ddof=1)

t1 = stats.t.ppf(alpha / 2, df=n - 1)
t2 = stats.t.ppf(1 - alpha / 2, df=n - 1)

t1, t2
# Out:
# (-2.2621571627409915, 2.2621571627409915)

# %%
# Доверительный интервал:
(mean + t1 * std / np.sqrt(n), mean + t2 * std / np.sqrt(n))
# Out:
# (110.55608365158724, 125.64391634841274)

# %% [markdown]
# __Задача 3__
#
# Известно, что рост футболистов в сборной распределен нормально с известной дисперсией 25. На выборке объёма 27 выборочное среднее составило 174.2. Найдите доверительный интервал для математического ожидания с надежностью 0.95.

# %%
variance = 25
n = 27
mean = 174.2
p = 0.95
alpha = 1 - p

x1 = stats.norm.ppf(alpha / 2)
x2 = stats.norm.ppf(1 - alpha / 2)

x1, x2
# Out:
# (-1.959963984540054, 1.959963984540054)

# %%
# Доверительный интервал:
(mean + x1 * np.sqrt(variance) / np.sqrt(n), mean + x2 * np.sqrt(variance) / np.sqrt(n))
# Out:
# (172.3140237765397, 176.08597622346028)

# %% [markdown]
# __Задача 4__
#
# Выберите тему для проектной работы по курсу Теории вероятностей и математической статистики и напишите ее в комментарии к Практическому заданию.
